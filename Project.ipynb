# %%
#Importing the required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
#Reading the dataset (csv file) and storing it in a dataframe named as df

df = pd.read_csv("stress_data.csv")
df.info()
df['BMI Category'].unique()
df['Stress Level'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   374 non-null    object
#  1   Age                      374 non-null    int64
#  2   Sleep Duration           374 non-null    float64
#  3   Quality of Sleep         374 non-null    int64
#  4   Physical Activity Level  374 non-null    int64
#  5   BMI Category             374 non-null    object
#  6   Heart Rate               374 non-null    int64
#  7   Daily Steps              374 non-null    int64
#  8   Stress Level             374 non-null    int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 26.4+ KB
# Stress Level
# 3    71
# 8    70
# 4    70
# 5    67
# 7    50
# 6    46
# Name: count, dtype: int64

# %%
#Storing the data features in x and output values in y.

x = df[['Gender', 'Age', 'BMI Category', 'Sleep Duration', 'Quality of Sleep', 'Physical Activity Level', 'Heart Rate', 'Daily Steps']]
y = df['Stress Level']

#Creating two dictionary to change string values to int values
label_encode = {"Gender": {"Male":0, "Female":1}}
label_encode1 = {"BMI Category": {"Normal":0, "Overweight":1, "Obese":2}}

#Replacing the strings with int values using .replace()
df.replace(label_encode, inplace=True)
df.replace(label_encode1, inplace=True)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   374 non-null    int64
#  1   Age                      374 non-null    int64
#  2   Sleep Duration           374 non-null    float64
#  3   Quality of Sleep         374 non-null    int64
#  4   Physical Activity Level  374 non-null    int64
#  5   BMI Category             374 non-null    int64
#  6   Heart Rate               374 non-null    int64
#  7   Daily Steps              374 non-null    int64
#  8   Stress Level             374 non-null    int64
# dtypes: float64(1), int64(8)
# memory usage: 26.4 KB
#    Gender  Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0       0   27             6.1                 6                       42
# 1       0   28             6.2                 6                       60
# 2       0   28             6.2                 6                       60
# 3       0   28             5.9                 4                       30
# 4       0   28             5.9                 4                       30
#
#    BMI Category  Heart Rate  Daily Steps  Stress Level
# 0             1          77         4200             6
# 1             0          75        10000             8
# 2             0          75        10000             8
# 3             2          85         3000             8
# 4             2          85         3000             8

# %%
#Standardising the x values using StandardScaler()

standardise = StandardScaler()
x = standardise.fit_transform(x)
x = pd.DataFrame(x)
x.describe()
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.989361 -1.753096  1.004126 -1.298887 -1.098280 -0.825418  1.654719
# 1 -0.989361 -1.637643 -0.818899 -1.173036 -1.098280  0.039844  1.170474
# 2 -0.989361 -1.637643 -0.818899 -1.173036 -1.098280  0.039844  1.170474
# 3 -0.989361 -1.637643  2.827150 -1.550588 -2.771424 -1.402260  3.591698
# 4 -0.989361 -1.637643  2.827150 -1.550588 -2.771424 -1.402260  3.591698
#
#           7
# 0 -1.619584
# 1  1.970077
# 2  1.970077
# 3 -2.362273
# 4 -2.362273

# %%
#Creating the neural network

model = Sequential()
model.add(Dense(9, input_dim=8, activation='relu'))
model.add(Dense(9, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 81
#
#  dense_1 (Dense)             (None, 9)                 90
#
#  dense_2 (Dense)             (None, 10)                100
#
# =================================================================
# Total params: 271 (1.06 KB)
# Trainable params: 271 (1.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Splitting the data into train and test data using train_test_split()

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=7)

#Standardising the train and test data

standardise = StandardScaler()
x_train = standardise.fit_transform(x_train)
x_test = standardise.transform(x_test)

#Fitting the model using train and test data
model.fit(x_train, y_train, epochs=60, shuffle=True, validation_data=(x_test, y_test), batch_size=1)
# Out:
# Epoch 1/60
# 280/280 [==============================] - 2s 3ms/step - loss: 1.9420 - accuracy: 0.2857 - val_loss: 1.6217 - val_accuracy: 0.5000
# Epoch 2/60
# 280/280 [==============================] - 1s 2ms/step - loss: 1.4880 - accuracy: 0.5714 - val_loss: 1.1892 - val_accuracy: 0.6277
# Epoch 3/60
# 280/280 [==============================] - 1s 2ms/step - loss: 1.1529 - accuracy: 0.7429 - val_loss: 0.8609 - val_accuracy: 0.8936
# Epoch 4/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.9142 - accuracy: 0.8536 - val_loss: 0.6449 - val_accuracy: 0.9362
# Epoch 5/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.7389 - accuracy: 0.8821 - val_loss: 0.5254 - val_accuracy: 0.9043
# Epoch 6/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.6079 - accuracy: 0.8857 - val_loss: 0.4189 - val_accuracy: 0.9043
# Epoch 7/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.5133 - accuracy: 0.8857 - val_loss: 0.3658 - val_accuracy: 0.9043
# Epoch 8/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.4470 - accuracy: 0.8857 - val_loss: 0.3313 - val_accuracy: 0.9149
# Epoch 9/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.4009 - accuracy: 0.8964 - val_loss: 0.2824 - val_accuracy: 0.9149
# Epoch 10/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.3636 - accuracy: 0.8929 - val_loss: 0.2577 - val_accuracy: 0.9149
# Epoch 11/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.3339 - accuracy: 0.9036 - val_loss: 0.2424 - val_accuracy: 0.9149
# Epoch 12/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.3098 - accuracy: 0.8964 - val_loss: 0.2349 - val_accuracy: 0.9149
# Epoch 13/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.2888 - accuracy: 0.9036 - val_loss: 0.2123 - val_accuracy: 0.9255
# Epoch 14/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.2708 - accuracy: 0.9107 - val_loss: 0.1966 - val_accuracy: 0.9255
# Epoch 15/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.2547 - accuracy: 0.9107 - val_loss: 0.1879 - val_accuracy: 0.9362
# Epoch 16/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.2432 - accuracy: 0.9179 - val_loss: 0.1764 - val_accuracy: 0.9468
# Epoch 17/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.2292 - accuracy: 0.9179 - val_loss: 0.1620 - val_accuracy: 0.9362
# Epoch 18/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.2177 - accuracy: 0.9286 - val_loss: 0.1627 - val_accuracy: 0.9468
# Epoch 19/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.2069 - accuracy: 0.9179 - val_loss: 0.1555 - val_accuracy: 0.9468
# Epoch 20/60
# 280/280 [==============================] - 1s 3ms/step - loss: 0.1961 - accuracy: 0.9321 - val_loss: 0.1386 - val_accuracy: 0.9362
# Epoch 21/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1848 - accuracy: 0.9357 - val_loss: 0.1329 - val_accuracy: 0.9574
# Epoch 22/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1778 - accuracy: 0.9357 - val_loss: 0.1230 - val_accuracy: 0.9574
# Epoch 23/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1685 - accuracy: 0.9286 - val_loss: 0.1213 - val_accuracy: 0.9574
# Epoch 24/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1619 - accuracy: 0.9393 - val_loss: 0.1217 - val_accuracy: 0.9574
# Epoch 25/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1539 - accuracy: 0.9500 - val_loss: 0.1093 - val_accuracy: 0.9681
# Epoch 26/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1446 - accuracy: 0.9500 - val_loss: 0.1015 - val_accuracy: 0.9681
# Epoch 27/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1362 - accuracy: 0.9607 - val_loss: 0.1078 - val_accuracy: 0.9574
# Epoch 28/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1312 - accuracy: 0.9643 - val_loss: 0.1011 - val_accuracy: 0.9681
# Epoch 29/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1239 - accuracy: 0.9643 - val_loss: 0.0950 - val_accuracy: 0.9681
# Epoch 30/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1177 - accuracy: 0.9643 - val_loss: 0.0931 - val_accuracy: 0.9574
# Epoch 31/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1110 - accuracy: 0.9679 - val_loss: 0.0726 - val_accuracy: 0.9787
# Epoch 32/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1083 - accuracy: 0.9679 - val_loss: 0.0798 - val_accuracy: 0.9787
# Epoch 33/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.1036 - accuracy: 0.9714 - val_loss: 0.0818 - val_accuracy: 0.9681
# Epoch 34/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0992 - accuracy: 0.9714 - val_loss: 0.0799 - val_accuracy: 0.9787
# Epoch 35/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0957 - accuracy: 0.9714 - val_loss: 0.0700 - val_accuracy: 0.9787
# Epoch 36/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0910 - accuracy: 0.9786 - val_loss: 0.0750 - val_accuracy: 0.9787
# Epoch 37/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0857 - accuracy: 0.9786 - val_loss: 0.0675 - val_accuracy: 0.9681
# Epoch 38/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0834 - accuracy: 0.9821 - val_loss: 0.0773 - val_accuracy: 0.9787
# Epoch 39/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0808 - accuracy: 0.9714 - val_loss: 0.0670 - val_accuracy: 0.9681
# Epoch 40/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0751 - accuracy: 0.9821 - val_loss: 0.0645 - val_accuracy: 0.9787
# Epoch 41/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0711 - accuracy: 0.9786 - val_loss: 0.0609 - val_accuracy: 0.9787
# Epoch 42/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0679 - accuracy: 0.9821 - val_loss: 0.0620 - val_accuracy: 0.9787
# Epoch 43/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0646 - accuracy: 0.9786 - val_loss: 0.0611 - val_accuracy: 0.9681
# Epoch 44/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0598 - accuracy: 0.9821 - val_loss: 0.0795 - val_accuracy: 0.9681
# Epoch 45/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0561 - accuracy: 0.9857 - val_loss: 0.0710 - val_accuracy: 0.9681
# Epoch 46/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0520 - accuracy: 0.9893 - val_loss: 0.0703 - val_accuracy: 0.9681
# Epoch 47/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0517 - accuracy: 0.9929 - val_loss: 0.0581 - val_accuracy: 0.9681
# Epoch 48/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0479 - accuracy: 0.9893 - val_loss: 0.0662 - val_accuracy: 0.9681
# Epoch 49/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0447 - accuracy: 0.9964 - val_loss: 0.0833 - val_accuracy: 0.9681
# Epoch 50/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0430 - accuracy: 0.9964 - val_loss: 0.0575 - val_accuracy: 0.9787
# Epoch 51/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0391 - accuracy: 0.9929 - val_loss: 0.0657 - val_accuracy: 0.9681
# Epoch 52/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0372 - accuracy: 0.9929 - val_loss: 0.0567 - val_accuracy: 0.9681
# Epoch 53/60
# 280/280 [==============================] - 1s 2ms/step - loss: 0.0360 - accuracy: 0.9929 - val_loss: 0.0694 - val_accuracy: 0.9681
# Epoch 54/60
# 103/280 [==========>...................] - ETA: 0s - loss: 0.0348 - accuracy: 0.9903

# %%
#Reading the prediction dataset (csv file) and storing it in a dataframe named as df2
df2 = pd.read_csv('predict_data.csv')

# %%
#Storing the data features in x_predict
x_predict = df2[['Gender', 'Age', 'BMI Category', 'Sleep Duration', 'Quality of Sleep', 'Physical Activity Level', 'Heart Rate', 'Daily Steps']]

label = {"Gender": {"Male":0, "Female":1}}
label1 = {"BMI Category": {"Normal":0, "Overweight":1, "Obese":2}}
df2.replace(label, inplace=True)
df2.replace(label1, inplace=True)
df2.head()

# %%
#Standardising the x values using StandardScaler()
x_predict = standardise.fit_transform(x_predict)
x_predict = pd.DataFrame(x_predict)
x_predict.head()

# %%
#Predicting the output and storing it in y_predict
y_predict= model.predict(x_predict)

# %%
#Displaying the output
stress_level = []
for i in range(0,y_predict.shape[0]):
    stress_level.append(np.argmax(y_predict[i,:]))
print(stress_level)
